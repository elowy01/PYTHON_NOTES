# %% [markdown]
# # About DataFrames
#
# This notebook contains general information on Pandas dataframes and the basic commands that one can use with them
#
# ## Creating dataframes
#
# ### From a .csv file
# In the following examples, I am going to use a .csv file named `backtesting.csv` from a FOREX project I've been working with and I am going to create a dataframe from it using Pandas `read_csv` method:

# %%
import pandas as pd
import numpy as np

# %matplotlib inline

# read-in the data frame from csv file
DF=pd.read_csv('../DATA/backtesting.csv')

# %% [markdown]
# Also, if the dataframe starts with a commented line we can skip it by doing:

# %%
DFtest1=pd.read_csv('../DATA/backtesting.csv',comment='#')

# %% [markdown]
# Now, if we want also to add some column names:

# %%
DFtest2=pd.read_csv('../DATA/backtesting.csv',comment='#',names=['colname1','colname2'])

# %% [markdown]
# read_csv allows also to read certain columns from the file

# %%
DFtest3=pd.read_csv("../DATA/backtesting.csv", usecols=[2]) # usecols works with 0-indexed columns

# %% [markdown]
# ### Creating a dataframe from a dictionary

# %%
d = {'col1': [1, 2, 3], 'col2': [3, 4, 5]}
df = pd.DataFrame(data=d)

# %% [markdown]
# ## Exploring the Dataframe

# %% [markdown]
# Good!, now we can inspect this new dataframe:

# %%
# returns a tuple with number of rows/columns
DF.shape
# Out:
# (86, 11)

# %% [markdown]
# In order to have basic information the DataFrame:

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 11 columns):
# End of trend                 86 non-null object
# RSI                          86 non-null float64
# Divergence                   86 non-null bool
# Number of bounces            86 non-null int64
# Trend length before(bars)    86 non-null int64
# Currency Pair                86 non-null object
# Direction                    86 non-null object
# Entry Time-frame             86 non-null object
# Reversed                     86 non-null bool
# Trend length after (bars)    69 non-null float64
# Ranging                      86 non-null bool
# dtypes: bool(3), float64(2), int64(2), object(4)
# memory usage: 5.7+ KB

# %% [markdown]
# And we can also take a look to the first rows of the dataframe:

# %%
DF.head(3) #only the 3 first lines are shown
# Out:
#        End of trend   RSI  Divergence  Number of bounces  \
# 0  23/04/2008 03:00  60.0        True                  2
# 1  06/05/2008 03:00  39.0       False                  0
# 2  27/05/2008 03:00  54.0       False                  0
#
#    Trend length before(bars) Currency Pair              Direction  \
# 0                         53       EUR/USD                     up
# 1                          7       EUR/USD  down (within uptrend)
# 2                          5       EUR/USD                     up
#
#   Entry Time-frame  Reversed  Trend length after (bars)  Ranging
# 0                D      True                      132.0    False
# 1                D     False                        NaN    False
# 2                D      True                        6.0     True

# %% [markdown]
# In order to know whe column names:

# %%
DF.columns
# Out:
# Index(['End of trend', 'RSI', 'Divergence', 'Number of bounces',
#        'Trend length before(bars)', 'Currency Pair', 'Direction',
#        'Entry Time-frame', 'Reversed', 'Trend length after (bars)', 'Ranging'],
#       dtype='object')

# %% [markdown]
# If we want to check a particular column from the dataframe ('RSI' for example):

# %%
RSI=DF[['RSI']]

# %% [markdown]
# If we want to select 2 non consecutive columns:

# %%
a=DF[['RSI','Ranging']]

# %% [markdown]
# ### Selecting using .iloc and .loc
# Extracted from:
# https://www.shanelynn.ie/select-pandas-dataframe-rows-and-columns-using-iloc-loc-and-ix/
#
# #### .iloc<br>
# Single selection:<br>
# * Rows:<br>
# data.iloc[0] # first row of data frame (Aleshia Tomkiewicz) - Note a Series data type output.<br>
# data.iloc[1] # second row of data frame (Evan Zigomalas)<br>
# data.iloc[-1] # last row of data frame (Mi Richan)<br>
# * Columns:<br>
# data.iloc[:,0] # first column of data frame (first_name)<br>
# data.iloc[:,1] # second column of data frame (last_name)<br>
# data.iloc[:,-1] # last column of data frame (id)<br>
#
# Multiple selection:<br>
# <br>
# data.iloc[0:5] # first five rows of dataframe<br>
# data.iloc[:, 0:2] # first two columns of data frame with all rows<br>
# data.iloc[[0,3,6,24], [0,5,6]] # 1st, 4th, 7th, 25th row + 1st 6th 7th columns.<br>
# data.iloc[0:5, 5:8] # first 5 rows and 5th, 6th, 7th columns of data frame (county -> phone1)<br>
#
# #### .loc<br>
# Single selection:<br>
# a=DF.loc[:,'Direction']<br>
#
# Multiple selection:<br>
# a=DF.loc[:,['Direction','RSI']]

# %% [markdown]
# ### Objects returned by .iloc and .loc
#
# * If only one row is selected then we will get a Pandas series:<br>
# data.iloc[0]
# * If we use list selector then we get a Dataframe:<br>
# data.iloc[[0]]
# * If we select multiple rows then we get a Dataframe:<br>
# data.iloc[0:5]

# %%
ix='RSI'

DF.loc[:,ix]
# Out:
# 0     60.0
# 1     39.0
# 2     54.0
# 3     42.0
# 4     43.0
# 5     61.0
# 6     20.6
# 7     17.0
# 8     58.0
# 9     20.6
# 10    77.0
# 11    41.0
# 12    72.0
# 13    42.0
# 14    72.0
# 15    48.0
# 16    52.0
# 17    47.0
# 18    64.0
# 19    72.0
# 20    62.0
# 21    26.0
# 22    50.0
# 23    27.0
# 24    23.0
# 25    30.0
# 26    71.0
# 27    72.0
# 28    66.0
# 29    27.0
#       ...
# 56    32.0
# 57    57.0
# 58    38.0
# 59    73.0
# 60    25.0
# 61    68.0
# 62    40.0
# 63    59.0
# 64    39.0
# 65    29.0
# 66    28.0
# 67    59.0
# 68    24.0
# 69    57.0
# 70    43.0
# 71    54.0
# 72    51.0
# 73    28.0
# 74    41.0
# 75    26.0
# 76    28.0
# 77    39.0
# 78    30.0
# 79    39.0
# 80    49.0
# 81    20.0
# 82    45.0
# 83    27.0
# 84    32.0
# 85    31.0
# Name: RSI, Length: 86, dtype: float64

# %% [markdown]
# ### Logical selection

# %% [markdown]
# And for example, if we want to select all records for which the 'Reversed' column is TRUE:

# %%
reversed_true=DF.loc[DF['Reversed']==True]

# %% [markdown]
# And if we want to select based in either the value of one column or a different one:

# %%
DF.loc[(DF['Reversed']==True) | DF['Divergence']==True]
# Out:
#         End of trend   RSI  Divergence  Number of bounces  \
# 0   23/04/2008 03:00  60.0        True                  2
# 2   27/05/2008 03:00  54.0       False                  0
# 4   16/06/2008 03:00  43.0       False                  0
# 5   15/07/2008 03:00  61.0       False                  0
# 7    12/9/2008 03:00  17.0       False                  2
# 8    23/9/2008 03:00  58.0       False                  0
# 9   28/10/2008 03:00  20.6        True                  5
# 10  19/12/2008 03:00  77.0       False                  0
# 11  05/03/2009 03:00  41.0        True                  0
# 12  20/03/2009 03:00  72.0       False                  0
# 13  22/04/2009 03:00  42.0       False                  0
# 17  09/07/2009 03:00  47.0       False                  0
# 18  05/08/2009 03:00  64.0        True                  2
# 19  24/09/2009 03:00  72.0       False                  3
# 20   1/12/2009 03:00  62.0        True                  5
# 22  13/01/2010 03:00  50.0       False                  0
# 25  08/06/2010 03:00  30.0        True                  6
# 27  10/08/2010 03:00  72.0       False                  2
# 28  05/11/2010 03:00  66.0        True                  8
# 29  01/12/2010 03:00  27.0        True                  0
# 30  06/12/2010 03:00  45.0        True                  0
# 31  04/01/2011 03:00  56.0        True                  0
# 32  11/01/2011 03:00  38.0        True                  1
# 33  11/03/2011 03:00  55.0       False                  0
# 35  02/05/2011 03:00  73.0        True                  2
# 36  17/06/2011 03:00  43.0       False                  0
# 37  05/07/2011 03:00  57.0       False                  0
# 39  30/08/2011 03:00  55.0       False                  0
# 41  05/10/2011 03:00  28.0       False                  2
# 42  31/10/2011 03:00  67.0       False                  0
# ..               ...   ...         ...                ...
# 55  28/03/2013 03:00  36.0        True                  1
# 56  10/07/2013 03:00  32.0       False                  0
# 57  22/08/2013 03:00  57.0       False                  0
# 58  06/09/2013 03:00  38.0       False                  0
# 59  28/10/2013 03:00  73.0       False                  2
# 60  17/03/2015 03:00  25.0       False                  8
# 61  18/05/2015 03:00  68.0        True                  1
# 62  27/05/2015 03:00  40.0       False                  0
# 63  23/06/2015 03:00  59.0       False                  0
# 64  21/07/2015 03:00  39.0       False                  0
# 65  02/12/2015 03:00  29.0        True                  2
# 66  25/10/2016 03:00  28.0       False                  0
# 67  07/11/2016 03:00  59.0       False                  0
# 68  25/11/2016 03:00  24.0       False                  1
# 69  21/12/2016 03:00  57.0        True                  2
# 70  11/04/2017 03:00  43.0       False                  0
# 71  12/05/2017 03:00  54.0       False                  0
# 72  21/06/2017 03:00  51.0       False                  3
# 74  18/05/2009 03:00  41.0       False                  1
# 75  03/06/2009 03:00  26.0       False                  2
# 76  16/10/2009 03:00  28.0       False                  0
# 77  18/01/2010 03:00  39.0       False                  0
# 78  03/05/2011 03:00  30.0       False                  1
# 79  27/07/2011 03:00  39.0        True                  2
# 80  27/11/2014 03:00  49.0       False                  0
# 81  26/07/2017 03:00  20.0       False                  4
# 82  16/08/2017 03:00  45.0       False                  5
# 83  12/09/2017 03:00  27.0        True                  6
# 84  08/06/2010 03:00  32.0        True                  2
# 85  04/06/2012 03:00  31.0        True                  2
#
#     Trend length before(bars) Currency Pair              Direction  \
# 0                          53       EUR/USD                     up
# 2                           5       EUR/USD                     up
# 4                           4       EUR/USD                   down
# 5                          20       EUR/USD                     up
# 7                          43       EUR/USD                   down
# 8                           6       EUR/USD  up (within downtrend)
# 9                          70       EUR/USD                   down
# 10                         13       EUR/USD                     up
# 11                         56       EUR/USD                   down
# 12                         11       EUR/USD                     up
# 13                         22       EUR/USD  down (within uptrend)
# 17                          5       EUR/USD                   down
# 18                         75       EUR/USD                     up
# 19                        109       EUR/USD                     up
# 20                        160       EUR/USD                     up
# 22                         14       EUR/USD  up (within downtrend)
# 25                        132       EUR/USD                   down
# 27                         44       EUR/USD                     up
# 28                         40       EUR/USD                     up
# 29                         17       EUR/USD                   down
# 30                          2       EUR/USD                     up
# 31                          3       EUR/USD                     up
# 32                         48       EUR/USD                   down
# 33                          3       EUR/USD  down (within uptrend)
# 35                         78       EUR/USD                     up
# 36                          5       EUR/USD                   down
# 37                          5       EUR/USD                     up
# 39                         15       EUR/USD                     up
# 41                         24       EUR/USD                   down
# 42                         17       EUR/USD                     up
# ..                        ...           ...                    ...
# 55                         37       EUR/USD                   down
# 56                         13       EUR/USD                   down
# 57                         30       EUR/USD                     up
# 58                          6       EUR/USD  down (within uptrend)
# 59                         34       EUR/USD                     up
# 60                        217       EUR/USD                   down
# 61                         23       EUR/USD                     up
# 62                          7       EUR/USD                   down
# 63                         15       EUR/USD                     up
# 64                         20       EUR/USD                   down
# 65                         32       EUR/USD                   down
# 66                         46       EUR/USD                   down
# 67                          9       EUR/USD  up (within downtrend)
# 68                         13       EUR/USD                   down
# 69                         32       EUR/USD                   down
# 70                          9       EUR/USD  down (within uptrend)
# 71                          3       EUR/USD  down (within uptrend)
# 72                         11       EUR/USD  down (within uptrend)
# 74                          4       USD/CAD  up (within downtrend)
# 75                         59       USD/CAD                   down
# 76                          8       USD/CAD                   down
# 77                         20       USD/CAD                   down
# 78                        172       USD/CAD                   down
# 79                        230       USD/CAD                   down
# 80                         10       USD/CAD  down (within uptrend)
# 81                         55       USD/CAD                   down
# 82                         12       USD/CAD  up (within downtrend)
# 83                         91       USD/CAD                   down
# 84                         25       AUD/USD                   down
# 85                         65       AUD/USD                   down
#
#    Entry Time-frame  Reversed  Trend length after (bars)  Ranging
# 0                 D      True                      132.0    False
# 2                 D      True                        6.0     True
# 4                 D      True                       20.0     True
# 5                 D      True                       41.0     True
# 7                 D      True                        8.0    False
# 8                 D      True                       24.0    False
# 9                 D      True                       36.0    False
# 10                D      True                       42.0    False
# 11                D      True                      189.0    False
# 12                D      True                       20.0    False
# 13                D      True                      156.0    False
# 17                D      True                       17.0     True
# 18                D     False                        NaN    False
# 19                D      True                        6.0    False
# 20                D      True                      134.0    False
# 22                D      True                      103.0    False
# 25                D      True                      232.0    False
# 27                D      True                       11.0    False
# 28                D      True                       46.0    False
# 29                D     False                        NaN    False
# 30                D     False                        NaN     True
# 31                D      True                        4.0     True
# 32                D      True                       79.0     True
# 33                D      True                       33.0    False
# 35                D      True                      316.0    False
# 36                D      True                       10.0     True
# 37                D      True                        6.0     True
# 39                D      True                       24.0     True
# 41                D      True                       17.0    False
# 42                D      True                       55.0    False
# ..              ...       ...                        ...      ...
# 55                D      True                       12.0    False
# 56                D      True                       20.0     True
# 57                D      True                       10.0    False
# 58                D      True                       33.0    False
# 59                D      True                        9.0    False
# 60                D      True                        8.0    False
# 61                D      True                        7.0     True
# 62                D      True                       16.0     True
# 63                D      True                       18.0     True
# 64                D      True                       25.0     True
# 65                D      True                      107.0    False
# 66                D      True                        9.0    False
# 67                D      True                       13.0    False
# 68                D      True                        7.0    False
# 69                D      True                      178.0    False
# 70                D      True                       98.0    False
# 71                D      True                       86.0    False
# 72                D      True                       47.0    False
# 74                D      True                       10.0    False
# 75                D      True                       25.0    False
# 76                D      True                        8.0    False
# 77                D      True                        9.0     True
# 78                D      True                       10.0    False
# 79                D      True                       48.0    False
# 80                D      True                       47.0    False
# 81                D      True                       11.0    False
# 82                D      True                       16.0    False
# 83                D      True                       35.0    False
# 84                D      True                       95.0    False
# 85                D      True                       44.0    False
#
# [70 rows x 11 columns]

# %% [markdown]
# Now, if we want the counts (frequencies) for a certain categorical variable we have to enter the following:

# %%
DF['Currency Pair'].value_counts()
# Out:
# EUR/USD    73
# USD/CAD    11
# AUD/USD     2
# Name: Currency Pair, dtype: int64

# %% [markdown]
# Now, if we want to copy the entire dataframe:

# %%
newDF = DF.copy()

newDF.head(3)
# Out:
#        End of trend   RSI  Divergence  Number of bounces  \
# 0  23/04/2008 03:00  60.0        True                  2
# 1  06/05/2008 03:00  39.0       False                  0
# 2  27/05/2008 03:00  54.0       False                  0
#
#    Trend length before(bars) Currency Pair              Direction  \
# 0                         53       EUR/USD                     up
# 1                          7       EUR/USD  down (within uptrend)
# 2                          5       EUR/USD                     up
#
#   Entry Time-frame  Reversed  Trend length after (bars)  Ranging
# 0                D      True                      132.0    False
# 1                D     False                        NaN    False
# 2                D      True                        6.0     True

# %% [markdown]
# ## Operations on the entire Dataframe
#
# ### Renaming the columns of the dataframe

# %%
newDF.columns=['newEnd of trend', 'RSI', 'Divergence', 'Number of bounces',
               'Trend length before(bars)', 'Currency Pair', 'Direction',
               'Entry Time-frame', 'Reversed', 'Trend length after (bars)', 'Ranging']

# %% [markdown]
# #### Renaming a certain column

# %%
DFren=DF.rename(columns={'RSI': 'RSINEW'})

# %% [markdown]
# ### Rounding all values in dataframe

# %%
DFrounded=DF.round(decimals=2)

# %% [markdown]
# ## Operations on the different variables in the Dataframe
#
# ### pd.crosstab
#
# The crosstab function can be used with the dataframe in order to create contigency tables to analyze the relationship between categorical variables.
# For example, let's analyze if there is a relationship between the probability of having a price reversal (`Reversed`= True) if there is divergence in the RSI indicator (`Divergence`=True):

# %%
div_class=pd.crosstab(DF['Divergence'], DF['Reversed'],margins=True)

print(div_class)
# Out:
# Reversed    False  True  All
# Divergence
# False          16    48   64
# True            3    19   22
# All            19    67   86

# %% [markdown]
# The 2x2 contigency table thas is above shows counts (including the Total row/columns counts. Now, if we want to calculate the proportion along each column:

# %%
div_class/div_class.loc["All"]
# Out:
# Reversed       False      True       All
# Divergence
# False       0.842105  0.716418  0.744186
# True        0.157895  0.283582  0.255814
# All         1.000000  1.000000  1.000000

# %% [markdown]
# ### pd.groupby
#
# This Pandas function is used to split the data depending on the categories of a certain variable. Then, a certain operation can be applied to the subgroups created after splitting the data and finally the different subgroups are combined into the final dataframe
#
# Let's see an example:

# %%
DF.groupby(['Divergence']).agg({'Trend length after (bars)': 'mean'})
# Out:
#             Trend length after (bars)
# Divergence
# False                       26.340000
# True                        97.947368

# %% [markdown]
# We split the dataframe into 2 subgroups depending on the values of the `Divergence` variable (TRUE/FALSE). And then, we calculate the mean for the variable `Trend length after (bars)` for each subgroup

# %% [markdown]
# Now, let's calculate the normalized value_counts for each category

# %%
grouped=DF.groupby(['Divergence'])
grouped['Currency Pair'].value_counts(normalize=True)
# Out:
# Divergence  Currency Pair
# False       EUR/USD          0.859375
#             USD/CAD          0.140625
# Name: Currency Pair, dtype: float64

# %% [markdown]
# ### pd.cut
#
# This Pandas function can be used to create bins based on the values of a continuous variable. In this way, we create discrete chunks that are used as ordinal categorical variables. For example:

# %%
pd.cut(np.array([.2, 1.4, 2.5, 6.2, 9.7, 2.1]), 3, retbins=True)
# Out:
# ([(0.19, 3.367], (0.19, 3.367], (0.19, 3.367], (3.367, 6.533], (6.533, 9.7], (0.19, 3.367]]
#  Categories (3, interval[float64]): [(0.19, 3.367] < (3.367, 6.533] < (6.533, 9.7]],
#  array([ 0.1905    ,  3.36666667,  6.53333333,  9.7       ]))

# %% [markdown]
# And if we want to create our own cut points we need to use a numpy array:

# %%
cuts = np.array([0,2,4,6,10])
pd.cut(np.array([.2, 1.4, 2.5, 6.2, 9.7, 2.1]), cuts)
# Out:
# [(0, 2], (0, 2], (2, 4], (6, 10], (6, 10], (2, 4]]
# Categories (4, interval[int64]): [(0, 2] < (2, 4] < (4, 6] < (6, 10]]

# %% [markdown]
# ### drop function
# This is used to drop a column from the dataframe. The original DF is not affected by this drop

# %%
newDF=DF.drop("RSI",axis=1)

# %% [markdown]
# ### copy function
# This function can be used in order to create a copy of a certain column in the DataFrame:

# %%
rsi_values=DF["RSI"].copy()

# %% [markdown]
# Now, let's duplicate a certain column in the DF (in this case we are adding a new column with these duplicated values)

# %%
DF.assign(RSI_copy = lambda x: x.RSI)
# Out:
#         End of trend   RSI  Divergence  Number of bounces  \
# 0   23/04/2008 03:00  60.0        True                  2
# 1   06/05/2008 03:00  39.0       False                  0
# 2   27/05/2008 03:00  54.0       False                  0
# 3   05/06/2008 03:00  42.0       False                  0
# 4   16/06/2008 03:00  43.0       False                  0
# 5   15/07/2008 03:00  61.0       False                  0
# 6   13/08/2008 03:00  20.6       False                  0
# 7    12/9/2008 03:00  17.0       False                  2
# 8    23/9/2008 03:00  58.0       False                  0
# 9   28/10/2008 03:00  20.6        True                  5
# 10  19/12/2008 03:00  77.0       False                  0
# 11  05/03/2009 03:00  41.0        True                  0
# 12  20/03/2009 03:00  72.0       False                  0
# 13  22/04/2009 03:00  42.0       False                  0
# 14  04/06/2009 03:00  72.0       False                  1
# 15  17/06/2009 03:00  48.0       False                  0
# 16  02/07/2009 03:00  52.0       False                  0
# 17  09/07/2009 03:00  47.0       False                  0
# 18  05/08/2009 03:00  64.0        True                  2
# 19  24/09/2009 03:00  72.0       False                  3
# 20   1/12/2009 03:00  62.0        True                  5
# 21  23/12/2009 03:00  26.0       False                  0
# 22  13/01/2010 03:00  50.0       False                  0
# 23  02/02/2010 03:00  27.0       False                  1
# 24  20/05/2010 03:00  23.0       False                  5
# 25  08/06/2010 03:00  30.0        True                  6
# 26  19/07/2010 03:00  71.0       False                  0
# 27  10/08/2010 03:00  72.0       False                  2
# 28  05/11/2010 03:00  66.0        True                  8
# 29  01/12/2010 03:00  27.0        True                  0
# ..               ...   ...         ...                ...
# 56  10/07/2013 03:00  32.0       False                  0
# 57  22/08/2013 03:00  57.0       False                  0
# 58  06/09/2013 03:00  38.0       False                  0
# 59  28/10/2013 03:00  73.0       False                  2
# 60  17/03/2015 03:00  25.0       False                  8
# 61  18/05/2015 03:00  68.0        True                  1
# 62  27/05/2015 03:00  40.0       False                  0
# 63  23/06/2015 03:00  59.0       False                  0
# 64  21/07/2015 03:00  39.0       False                  0
# 65  02/12/2015 03:00  29.0        True                  2
# 66  25/10/2016 03:00  28.0       False                  0
# 67  07/11/2016 03:00  59.0       False                  0
# 68  25/11/2016 03:00  24.0       False                  1
# 69  21/12/2016 03:00  57.0        True                  2
# 70  11/04/2017 03:00  43.0       False                  0
# 71  12/05/2017 03:00  54.0       False                  0
# 72  21/06/2017 03:00  51.0       False                  3
# 73  12/05/2009 03:00  28.0       False                  0
# 74  18/05/2009 03:00  41.0       False                  1
# 75  03/06/2009 03:00  26.0       False                  2
# 76  16/10/2009 03:00  28.0       False                  0
# 77  18/01/2010 03:00  39.0       False                  0
# 78  03/05/2011 03:00  30.0       False                  1
# 79  27/07/2011 03:00  39.0        True                  2
# 80  27/11/2014 03:00  49.0       False                  0
# 81  26/07/2017 03:00  20.0       False                  4
# 82  16/08/2017 03:00  45.0       False                  5
# 83  12/09/2017 03:00  27.0        True                  6
# 84  08/06/2010 03:00  32.0        True                  2
# 85  04/06/2012 03:00  31.0        True                  2
#
#     Trend length before(bars) Currency Pair              Direction  \
# 0                          53       EUR/USD                     up
# 1                           7       EUR/USD  down (within uptrend)
# 2                           5       EUR/USD                     up
# 3                           6       EUR/USD                   down
# 4                           4       EUR/USD                   down
# 5                          20       EUR/USD                     up
# 6                          17       EUR/USD                   down
# 7                          43       EUR/USD                   down
# 8                           6       EUR/USD  up (within downtrend)
# 9                          70       EUR/USD                   down
# 10                         13       EUR/USD                     up
# 11                         56       EUR/USD                   down
# 12                         11       EUR/USD                     up
# 13                         22       EUR/USD  down (within uptrend)
# 14                         30       EUR/USD                     up
# 15                          2       EUR/USD                   down
# 16                          6       EUR/USD                     up
# 17                          5       EUR/USD                   down
# 18                         75       EUR/USD                     up
# 19                        109       EUR/USD                     up
# 20                        160       EUR/USD                     up
# 21                         15       EUR/USD                   down
# 22                         14       EUR/USD  up (within downtrend)
# 23                         43       EUR/USD                   down
# 24                        118       EUR/USD                   down
# 25                        132       EUR/USD                   down
# 26                         28       EUR/USD                     up
# 27                         44       EUR/USD                     up
# 28                         40       EUR/USD                     up
# 29                         17       EUR/USD                   down
# ..                        ...           ...                    ...
# 56                         13       EUR/USD                   down
# 57                         30       EUR/USD                     up
# 58                          6       EUR/USD  down (within uptrend)
# 59                         34       EUR/USD                     up
# 60                        217       EUR/USD                   down
# 61                         23       EUR/USD                     up
# 62                          7       EUR/USD                   down
# 63                         15       EUR/USD                     up
# 64                         20       EUR/USD                   down
# 65                         32       EUR/USD                   down
# 66                         46       EUR/USD                   down
# 67                          9       EUR/USD  up (within downtrend)
# 68                         13       EUR/USD                   down
# 69                         32       EUR/USD                   down
# 70                          9       EUR/USD  down (within uptrend)
# 71                          3       EUR/USD  down (within uptrend)
# 72                         11       EUR/USD  down (within uptrend)
# 73                         43       USD/CAD                   down
# 74                          4       USD/CAD  up (within downtrend)
# 75                         59       USD/CAD                   down
# 76                          8       USD/CAD                   down
# 77                         20       USD/CAD                   down
# 78                        172       USD/CAD                   down
# 79                        230       USD/CAD                   down
# 80                         10       USD/CAD  down (within uptrend)
# 81                         55       USD/CAD                   down
# 82                         12       USD/CAD  up (within downtrend)
# 83                         91       USD/CAD                   down
# 84                         25       AUD/USD                   down
# 85                         65       AUD/USD                   down
#
#    Entry Time-frame  Reversed  Trend length after (bars)  Ranging  RSI_copy
# 0                 D      True                      132.0    False      60.0
# 1                 D     False                        NaN    False      39.0
# 2                 D      True                        6.0     True      54.0
# 3                 D     False                        NaN     True      42.0
# 4                 D      True                       20.0     True      43.0
# 5                 D      True                       41.0     True      61.0
# 6                 D     False                        NaN    False      20.6
# 7                 D      True                        8.0    False      17.0
# 8                 D      True                       24.0    False      58.0
# 9                 D      True                       36.0    False      20.6
# 10                D      True                       42.0    False      77.0
# 11                D      True                      189.0    False      41.0
# 12                D      True                       20.0    False      72.0
# 13                D      True                      156.0    False      42.0
# 14                D     False                        NaN    False      72.0
# 15                D     False                        NaN     True      48.0
# 16                D     False                        NaN     True      52.0
# 17                D      True                       17.0     True      47.0
# 18                D     False                        NaN    False      64.0
# 19                D      True                        6.0    False      72.0
# 20                D      True                      134.0    False      62.0
# 21                D     False                        NaN    False      26.0
# 22                D      True                      103.0    False      50.0
# 23                D     False                        NaN    False      27.0
# 24                D     False                        NaN    False      23.0
# 25                D      True                      232.0    False      30.0
# 26                D     False                        NaN    False      71.0
# 27                D      True                       11.0    False      72.0
# 28                D      True                       46.0    False      66.0
# 29                D     False                        NaN    False      27.0
# ..              ...       ...                        ...      ...       ...
# 56                D      True                       20.0     True      32.0
# 57                D      True                       10.0    False      57.0
# 58                D      True                       33.0    False      38.0
# 59                D      True                        9.0    False      73.0
# 60                D      True                        8.0    False      25.0
# 61                D      True                        7.0     True      68.0
# 62                D      True                       16.0     True      40.0
# 63                D      True                       18.0     True      59.0
# 64                D      True                       25.0     True      39.0
# 65                D      True                      107.0    False      29.0
# 66                D      True                        9.0    False      28.0
# 67                D      True                       13.0    False      59.0
# 68                D      True                        7.0    False      24.0
# 69                D      True                      178.0    False      57.0
# 70                D      True                       98.0    False      43.0
# 71                D      True                       86.0    False      54.0
# 72                D      True                       47.0    False      51.0
# 73                D     False                        4.0    False      28.0
# 74                D      True                       10.0    False      41.0
# 75                D      True                       25.0    False      26.0
# 76                D      True                        8.0    False      28.0
# 77                D      True                        9.0     True      39.0
# 78                D      True                       10.0    False      30.0
# 79                D      True                       48.0    False      39.0
# 80                D      True                       47.0    False      49.0
# 81                D      True                       11.0    False      20.0
# 82                D      True                       16.0    False      45.0
# 83                D      True                       35.0    False      27.0
# 84                D      True                       95.0    False      32.0
# 85                D      True                       44.0    False      31.0
#
# [86 rows x 12 columns]

# %% [markdown]
# Now, if we want to create a new variable with the RSI values divided by two:

# %%
a=DF.assign(RSI_half = lambda x: x.RSI/2)

# %% [markdown]
# ### filling the na (or n.a. or missing values)
# There are different strategies for this:
# * Dropping the na values for each of the missing rows:

# %%
#In this case, we are dropping the na values from RSI
DF.dropna(subset=["RSI"])
# Out:
#         End of trend   RSI  Divergence  Number of bounces  \
# 0   23/04/2008 03:00  60.0        True                  2
# 1   06/05/2008 03:00  39.0       False                  0
# 2   27/05/2008 03:00  54.0       False                  0
# 3   05/06/2008 03:00  42.0       False                  0
# 4   16/06/2008 03:00  43.0       False                  0
# 5   15/07/2008 03:00  61.0       False                  0
# 6   13/08/2008 03:00  20.6       False                  0
# 7    12/9/2008 03:00  17.0       False                  2
# 8    23/9/2008 03:00  58.0       False                  0
# 9   28/10/2008 03:00  20.6        True                  5
# 10  19/12/2008 03:00  77.0       False                  0
# 11  05/03/2009 03:00  41.0        True                  0
# 12  20/03/2009 03:00  72.0       False                  0
# 13  22/04/2009 03:00  42.0       False                  0
# 14  04/06/2009 03:00  72.0       False                  1
# 15  17/06/2009 03:00  48.0       False                  0
# 16  02/07/2009 03:00  52.0       False                  0
# 17  09/07/2009 03:00  47.0       False                  0
# 18  05/08/2009 03:00  64.0        True                  2
# 19  24/09/2009 03:00  72.0       False                  3
# 20   1/12/2009 03:00  62.0        True                  5
# 21  23/12/2009 03:00  26.0       False                  0
# 22  13/01/2010 03:00  50.0       False                  0
# 23  02/02/2010 03:00  27.0       False                  1
# 24  20/05/2010 03:00  23.0       False                  5
# 25  08/06/2010 03:00  30.0        True                  6
# 26  19/07/2010 03:00  71.0       False                  0
# 27  10/08/2010 03:00  72.0       False                  2
# 28  05/11/2010 03:00  66.0        True                  8
# 29  01/12/2010 03:00  27.0        True                  0
# ..               ...   ...         ...                ...
# 56  10/07/2013 03:00  32.0       False                  0
# 57  22/08/2013 03:00  57.0       False                  0
# 58  06/09/2013 03:00  38.0       False                  0
# 59  28/10/2013 03:00  73.0       False                  2
# 60  17/03/2015 03:00  25.0       False                  8
# 61  18/05/2015 03:00  68.0        True                  1
# 62  27/05/2015 03:00  40.0       False                  0
# 63  23/06/2015 03:00  59.0       False                  0
# 64  21/07/2015 03:00  39.0       False                  0
# 65  02/12/2015 03:00  29.0        True                  2
# 66  25/10/2016 03:00  28.0       False                  0
# 67  07/11/2016 03:00  59.0       False                  0
# 68  25/11/2016 03:00  24.0       False                  1
# 69  21/12/2016 03:00  57.0        True                  2
# 70  11/04/2017 03:00  43.0       False                  0
# 71  12/05/2017 03:00  54.0       False                  0
# 72  21/06/2017 03:00  51.0       False                  3
# 73  12/05/2009 03:00  28.0       False                  0
# 74  18/05/2009 03:00  41.0       False                  1
# 75  03/06/2009 03:00  26.0       False                  2
# 76  16/10/2009 03:00  28.0       False                  0
# 77  18/01/2010 03:00  39.0       False                  0
# 78  03/05/2011 03:00  30.0       False                  1
# 79  27/07/2011 03:00  39.0        True                  2
# 80  27/11/2014 03:00  49.0       False                  0
# 81  26/07/2017 03:00  20.0       False                  4
# 82  16/08/2017 03:00  45.0       False                  5
# 83  12/09/2017 03:00  27.0        True                  6
# 84  08/06/2010 03:00  32.0        True                  2
# 85  04/06/2012 03:00  31.0        True                  2
#
#     Trend length before(bars) Currency Pair              Direction  \
# 0                          53       EUR/USD                     up
# 1                           7       EUR/USD  down (within uptrend)
# 2                           5       EUR/USD                     up
# 3                           6       EUR/USD                   down
# 4                           4       EUR/USD                   down
# 5                          20       EUR/USD                     up
# 6                          17       EUR/USD                   down
# 7                          43       EUR/USD                   down
# 8                           6       EUR/USD  up (within downtrend)
# 9                          70       EUR/USD                   down
# 10                         13       EUR/USD                     up
# 11                         56       EUR/USD                   down
# 12                         11       EUR/USD                     up
# 13                         22       EUR/USD  down (within uptrend)
# 14                         30       EUR/USD                     up
# 15                          2       EUR/USD                   down
# 16                          6       EUR/USD                     up
# 17                          5       EUR/USD                   down
# 18                         75       EUR/USD                     up
# 19                        109       EUR/USD                     up
# 20                        160       EUR/USD                     up
# 21                         15       EUR/USD                   down
# 22                         14       EUR/USD  up (within downtrend)
# 23                         43       EUR/USD                   down
# 24                        118       EUR/USD                   down
# 25                        132       EUR/USD                   down
# 26                         28       EUR/USD                     up
# 27                         44       EUR/USD                     up
# 28                         40       EUR/USD                     up
# 29                         17       EUR/USD                   down
# ..                        ...           ...                    ...
# 56                         13       EUR/USD                   down
# 57                         30       EUR/USD                     up
# 58                          6       EUR/USD  down (within uptrend)
# 59                         34       EUR/USD                     up
# 60                        217       EUR/USD                   down
# 61                         23       EUR/USD                     up
# 62                          7       EUR/USD                   down
# 63                         15       EUR/USD                     up
# 64                         20       EUR/USD                   down
# 65                         32       EUR/USD                   down
# 66                         46       EUR/USD                   down
# 67                          9       EUR/USD  up (within downtrend)
# 68                         13       EUR/USD                   down
# 69                         32       EUR/USD                   down
# 70                          9       EUR/USD  down (within uptrend)
# 71                          3       EUR/USD  down (within uptrend)
# 72                         11       EUR/USD  down (within uptrend)
# 73                         43       USD/CAD                   down
# 74                          4       USD/CAD  up (within downtrend)
# 75                         59       USD/CAD                   down
# 76                          8       USD/CAD                   down
# 77                         20       USD/CAD                   down
# 78                        172       USD/CAD                   down
# 79                        230       USD/CAD                   down
# 80                         10       USD/CAD  down (within uptrend)
# 81                         55       USD/CAD                   down
# 82                         12       USD/CAD  up (within downtrend)
# 83                         91       USD/CAD                   down
# 84                         25       AUD/USD                   down
# 85                         65       AUD/USD                   down
#
#    Entry Time-frame  Reversed  Trend length after (bars)  Ranging
# 0                 D      True                      132.0    False
# 1                 D     False                        NaN    False
# 2                 D      True                        6.0     True
# 3                 D     False                        NaN     True
# 4                 D      True                       20.0     True
# 5                 D      True                       41.0     True
# 6                 D     False                        NaN    False
# 7                 D      True                        8.0    False
# 8                 D      True                       24.0    False
# 9                 D      True                       36.0    False
# 10                D      True                       42.0    False
# 11                D      True                      189.0    False
# 12                D      True                       20.0    False
# 13                D      True                      156.0    False
# 14                D     False                        NaN    False
# 15                D     False                        NaN     True
# 16                D     False                        NaN     True
# 17                D      True                       17.0     True
# 18                D     False                        NaN    False
# 19                D      True                        6.0    False
# 20                D      True                      134.0    False
# 21                D     False                        NaN    False
# 22                D      True                      103.0    False
# 23                D     False                        NaN    False
# 24                D     False                        NaN    False
# 25                D      True                      232.0    False
# 26                D     False                        NaN    False
# 27                D      True                       11.0    False
# 28                D      True                       46.0    False
# 29                D     False                        NaN    False
# ..              ...       ...                        ...      ...
# 56                D      True                       20.0     True
# 57                D      True                       10.0    False
# 58                D      True                       33.0    False
# 59                D      True                        9.0    False
# 60                D      True                        8.0    False
# 61                D      True                        7.0     True
# 62                D      True                       16.0     True
# 63                D      True                       18.0     True
# 64                D      True                       25.0     True
# 65                D      True                      107.0    False
# 66                D      True                        9.0    False
# 67                D      True                       13.0    False
# 68                D      True                        7.0    False
# 69                D      True                      178.0    False
# 70                D      True                       98.0    False
# 71                D      True                       86.0    False
# 72                D      True                       47.0    False
# 73                D     False                        4.0    False
# 74                D      True                       10.0    False
# 75                D      True                       25.0    False
# 76                D      True                        8.0    False
# 77                D      True                        9.0     True
# 78                D      True                       10.0    False
# 79                D      True                       48.0    False
# 80                D      True                       47.0    False
# 81                D      True                       11.0    False
# 82                D      True                       16.0    False
# 83                D      True                       35.0    False
# 84                D      True                       95.0    False
# 85                D      True                       44.0    False
#
# [86 rows x 11 columns]

# %% [markdown]
# * Replacing the missing values with the median:

# %%
median = DF["RSI"].median()  # option 3
DF["RSI"].fillna(median, inplace=True)

# %% [markdown]
# * Selecting the null values in a dataframe column

# %%
df = pd.DataFrame([[1, 2, 3], [3, 4, None]]) #creating a df with a null value for column 2
df[df[2].isnull()]
# Out:
#    0  1   2
# 1  3  4 NaN

# %% [markdown]
# * Selecting the not null values in a dataframe column

# %%
df[df[2].notnull()]
# Out:
#    0  1    2
# 0  1  2  3.0

# %% [markdown]
# ### Changing the date type of an entire column
# Example extracted from https://code.i-harness.com/en/q/f27a5e

# %%
a = [['a', '1.2', '4.2'], ['b', '70', '0.03'], ['x', '5', '0']]
df = pd.DataFrame(a, columns=['one', 'two', 'three'])

df.dtypes
# Out:
# one      object
# two      object
# three    object
# dtype: object

# %%
df[['two', 'three']] = df[['two', 'three']].astype(float)

df.dtypes
# Out:
# one       object
# two      float64
# three    float64
# dtype: object

# %% [markdown]
# ### Working with dates
# We illustrate here how to work with dates. First, let's convert a date string element in the `End of trend` column into a datetime object:

# %%
adate_str=DF['End of trend'][0]

adate=pd.datetime.strptime(adate_str, '%d/%m/%Y %H:%M')

# %% [markdown]
# Now, we can perform arithmetic operations with this date. For example, we can substract a day:

# %%
D=pd.DateOffset(1)

adate_minus1=adate-D

# %% [markdown]
# Now, we can convert back this date object into a string:

# %%
adate_minus1.strftime('%d/%m/%Y %H:%M')
# Out:
# '22/04/2008 03:00'

# %% [markdown]
# Now, let's work on the entire column. Let's replace the data type of the `End of trend` column to datetime object:

# %%
DF['End of trend'] = pd.to_datetime(DF['End of trend'])

# %% [markdown]
# ### Deleting rows based on the value of one column
# Let's imagine that we want to remove from the dataframe all records where the value of 'Divergence' is True. This can be done in the following way:

# %%
DF = DF[DF.Divergence != True]

# %% [markdown]
# ## Applying functions on a dataframe

# %% [markdown]
# ### Apply function on a certain column
#
# * Using a lambda function

# %%
d = {'col1': [1, 2, 3], 'col2': [3, 4, 5]}
df = pd.DataFrame(data=d)

df['col1'] = df['col1'].apply(lambda x: x + 1)
print(df)
# Out:
#    col1  col2
# 0     2     3
# 1     3     4
# 2     4     5

# %% [markdown]
# * Conditional logic on a dataframe

# %%
df["logic"] = df["col1"] > 3
print(df)
# Out:
#    col1  col2  logic
# 0     2     3  False
# 1     3     4  False
# 2     4     5   True

# %% [markdown]
# * Applying a created function on a dataframe

# %%
# create a function called times100
def times100(x):
    # that, if x is a string,
    if type(x) is str:
        # just returns it untouched
        return x
    # but, if not, return it multiplied by 100
    elif x:
        return 100 * x
    # and leave everything else
    else:
        return
    
df.applymap(times100)
# Out:
#    col1  col2  logic
# 0   200   300    NaN
# 1   300   400    NaN
# 2   400   500  100.0

# %% [markdown]
# Now, apply the times100 function on a single column

# %%
df['col1'].apply(times100)
# Out:
# 0    200
# 1    300
# 2    400
# Name: col1, dtype: int64

# %% [markdown]
# ## Plots in a dataframe
#
# ### Hist on a certain column

# %%
DF.hist(column='Number of bounces')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1116ff2b0>]], dtype=object)

# %% [markdown]
# * Now, if we want to modify the axes, we need to access the list returned by the `hist` method

# %%
axList=DF.hist(column='Number of bounces')
axList[0][0].set_xlim((0,5))
# Out:
# (0, 5)

# %% [markdown]
# * Now, if we want to modify the figure size

# %%
DF.hist(column='Number of bounces',figsize=(5,5))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1138f1c50>]], dtype=object)

# %% [markdown]
# ### Hists based on the categories of a certain categorical variable

# %%
#creating the dataframe
x = ['A']*300 + ['B']*400 + ['C']*300
y = np.random.randn(1000)
df = pd.DataFrame({'Letter':x, 'N':y})
#plotting
df['N'].hist(by=df['Letter'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x113a9e048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113ac80b8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x113ad2f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113c40668>]], dtype=object)

# %% [markdown]
# * Now, if we want to modify the axes, we need to access the list returned by the `hist` method

# %%
axList=df['N'].hist(by=df['Letter'])
axList[0][0].set_xlim((0,5))
axList[0][1].set_xlim((0,5))
# Out:
# (0, 5)

# %% [markdown]
# ### Creating a bar plot

# %%
df = pd.DataFrame({'lab':['A', 'B', 'C'], 'val':[10, 30, 20]})
ax = df.plot.bar(x='lab', y='val', rot=0)

# %% [markdown]
# * Now, we can plot several numerical series grouped by categories

# %%
speed = [0.1, 17.5, 40, 48, 52, 69, 88]
lifespan = [2, 8, 70, 1.5, 25, 12, 28]
index = ['snail', 'pig', 'elephant',
         'rabbit', 'giraffe', 'coyote', 'horse']
df = pd.DataFrame({'speed': speed,
                   'lifespan': lifespan}, index=index)
ax = df.plot.bar(rot=0)

# %% [markdown]
# The figure can be split by column with subplots=True.

# %%
axes = df.plot.bar(rot=0, subplots=True)
axes[1].legend(loc=2)

# %% [markdown]
# ### Creating barplot with seaborn
# * Here we show how to create a countplot on a certain categorical variable

# %%
import seaborn as sns
sns.set(style="darkgrid")
titanic = sns.load_dataset("titanic")
titanic.head(5)
ax = sns.countplot(x="class", data=titanic)

# %% [markdown]
# * Countplot for two categorical variables

# %%
ax = sns.countplot(x="class", hue="who", data=titanic)

# %% [markdown]
# ### Creating scatter plots to see the correlation between numerical variables

# %%
df.plot(kind="scatter", x="speed", y="lifespan", alpha=0.1)

# %% [markdown]
# * Now, let's create a scatter plot matrix:

# %% [markdown]
# from pandas.plotting import scatter_matrix
#
# attributes = ["median_house_value", "median_income", "total_rooms",
#               "housing_median_age"]
# scatter_matrix(housing[attributes], figsize=(12, 8))
# save_fig("scatter_matrix_plot")

# %% [markdown]
# ## Saving a dataframe
# Saving a dataframe in .tsv format:

# %%
DF.to_csv('newDF.tsv',sep='\t')
