# %% [markdown]
# SNPs:

# %%
from matplotlib_venn import venn2_unweighted
from matplotlib.pyplot import figure
import matplotlib as mpl
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))

mpl.rcParams['font.size'] = 20

venn2_unweighted(subsets = (format(48085284,','),format(9095673,','),format(23841194,',')), set_labels = ('1KG', 'GGVP'))

plt.savefig('snvs_venn.pdf')

# %% [markdown]
# INDELs:

# %%
from matplotlib_venn import venn2_unweighted
from matplotlib.pyplot import figure
import matplotlib as mpl
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))

mpl.rcParams['font.size'] = 20

venn2_unweighted(subsets = (format(2866023,','),format(878051,','),format(2055046,',')), set_labels = ('1KG', 'GGVP'))

plt.savefig('indels_venn.pdf')
